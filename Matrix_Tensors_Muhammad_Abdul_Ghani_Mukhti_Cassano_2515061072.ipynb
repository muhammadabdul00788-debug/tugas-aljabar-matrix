# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[25, 15, 6], [1, 7, 2]])
X
# Out:
# array([[25, 15,  6],
#        [ 1,  7,  2]])

# %%
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:,0]
# Out:
# array([25,  1])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1,:]
# Out:
# array([1, 7, 2])

# %% [markdown]
# 2. ulangi soal nomor 1 menggunakan Pytorch

# %%
import torch

# %%
X_pt = torch.tensor([[25, 15, 6], [1, 7, 2]])
X_pt
# Out:
# tensor([[25, 15,  6],
#         [ 1,  7,  2]])

# %%
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
X_pt[:,0]
# Out:
# tensor([25,  1])

# %%
X_pt[1,:]
# Out:
# tensor([1, 7, 2])

# %% [markdown]
# 3.ulangi soal nomor 1 menggunakan Tensorflow

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[25, 15, 6], [1, 7, 2]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[25, 15,  6],
#        [ 1,  7,  2]], dtype=int32)>

# %%
X_tf.shape
# Out:
# TensorShape([2, 3])

# %%
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([25,  1], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 7, 2], dtype=int32)>
